# %% [markdown]
# # Scraping Wikipedia

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import html5lib

import requests 
from bs4 import BeautifulSoup
import urllib
import time
import ast

# %% [markdown]
# Firstly we got the relevant url

# %%
a = pd.read_html('https://en.wikipedia.org/wiki/List_of_current_UFC_fighters', flavor = 'html5lib')

# %% [markdown]
# Next we put each table into a seperate dataframe and added a weight class column and index. These will be useful later. We then merged all the dataframes into one big one.

# %%
a11 = a[11]
a11['Weight Class']='Heavyweight'
a11['Weight Class Index']= 0

a12 = a[12]
a12['Weight Class']='Light heavyweight'
a12['Weight Class Index']= 1

a13 = a[13]
a13['Weight Class']='Middleweight'
a13['Weight Class Index']= 2

a14 = a[14]
a14['Weight Class']='Welterweight'
a14['Weight Class Index']= 3

a15 = a[15]
a15['Weight Class']='Lightweight'
a15['Weight Class Index']= 4

a16 = a[16]
a16['Weight Class']='Featherweight'
a16['Weight Class Index']= 5

a17 = a[17]
a17['Weight Class']='Bantamweight'
a17['Weight Class Index']= 6

a18 = a[18]
a18['Weight Class']='Flyweight'
a18['Weight Class Index']= 7

a19 = a[19]
a19['Weight Class']='Women"s Featherweight'
a19['Weight Class Index']= 8

a20 = a[20]
a20['Weight Class']='Women"s Bantamweight'
a20['Weight Class Index']= 9

a21 = a[21]
a21['Weight Class']='Women"s Flyweight'
a21['Weight Class Index']= 10

a22 = a[22]
a22['Weight Class']='Women"s Strawweight'
a22['Weight Class Index']= 11


fighters = pd.concat([a11,a12,a13,a14,a15,a16,a17,a18,a19,a20,a21,a22])
fighters.head(5)
# Out:
#      0                   1    2                   3             4  \
# 0  ISO                Name  Age                 Ht.      Nickname
# 1  NaN   Andrei Arlovski *   40  6 ft 3 in (1.91 m)  The Pit Bull
# 2  NaN  Alistair Overeem *   38  6 ft 5 in (1.96 m)      The Reem
# 3  NaN      Cain Velasquez   36  6 ft 1 in (1.85 m)           NaN
# 4  NaN   Fabrício Werdum *   41  6 ft 4 in (1.93 m)    Vai Cavalo
#
#                                                    5      6                7  \
# 0                       Result / next fight / status    Ref  Endeavor record
# 1    Loss - UFC on ESPN+ 8 (Sunrise) - Augusto Sakai  [114]     16–12 (1 NC)
# 2  Win - UFC on ESPN+ 7 (St. Peterburg) - Alexey ...  [115]             11–6
# 3   Loss - UFC on ESPN 1 (Phoenix) - Francis Ngannou  [116]             12–3
# 4  USADA suspension for 2 years - for tested posi...   [79]             11–6
#
#               8 Weight Class  Weight Class Index
# 0    MMA record  Heavyweight                   0
# 1  27–18 (2 NC)  Heavyweight                   0
# 2  45–17 (1 NC)  Heavyweight                   0
# 3          14–3  Heavyweight                   0
# 4        23–8–1  Heavyweight                   0

# %% [markdown]
# Once again the first row had be changed to the column titles

# %%
fighters.columns = fighters.iloc[0]
fighters = fighters.drop(fighters.index[[0]])
fighters.reset_index(drop = True)
fighters.head(4)
# Out:
# 0  ISO                Name Age                 Ht.      Nickname  \
# 1  NaN   Andrei Arlovski *  40  6 ft 3 in (1.91 m)  The Pit Bull
# 2  NaN  Alistair Overeem *  38  6 ft 5 in (1.96 m)      The Reem
# 3  NaN      Cain Velasquez  36  6 ft 1 in (1.85 m)           NaN
# 4  NaN   Fabrício Werdum *  41  6 ft 4 in (1.93 m)    Vai Cavalo
#
# 0                       Result / next fight / status    Ref Endeavor record  \
# 1    Loss - UFC on ESPN+ 8 (Sunrise) - Augusto Sakai  [114]    16–12 (1 NC)
# 2  Win - UFC on ESPN+ 7 (St. Peterburg) - Alexey ...  [115]            11–6
# 3   Loss - UFC on ESPN 1 (Phoenix) - Francis Ngannou  [116]            12–3
# 4  USADA suspension for 2 years - for tested posi...   [79]            11–6
#
# 0    MMA record  Heavyweight  0
# 1  27–18 (2 NC)  Heavyweight  0
# 2  45–17 (1 NC)  Heavyweight  0
# 3          14–3  Heavyweight  0
# 4        23–8–1  Heavyweight  0

# %% [markdown]
# We then dropped any row without a name

# %%
fighters = fighters[fighters['Name'].notnull()]

# %% [markdown]
# The name column had to be cleaned with asterixs and "(C)" for champions removed

# %%
fighters['Name'] = fighters['Name'].map(lambda x: x.split('*')[0].strip())
fighters['Name'] = fighters['Name'].map(lambda x: x.split('(C)')[0].strip())

fighters.head(5)
# Out:
# 0  ISO               Name Age                 Ht.      Nickname  \
# 1  NaN    Andrei Arlovski  40  6 ft 3 in (1.91 m)  The Pit Bull
# 2  NaN   Alistair Overeem  38  6 ft 5 in (1.96 m)      The Reem
# 3  NaN     Cain Velasquez  36  6 ft 1 in (1.85 m)           NaN
# 4  NaN    Fabrício Werdum  41  6 ft 4 in (1.93 m)    Vai Cavalo
# 5  NaN  Junior dos Santos  35  6 ft 4 in (1.93 m)        Cigano
#
# 0                       Result / next fight / status    Ref Endeavor record  \
# 1    Loss - UFC on ESPN+ 8 (Sunrise) - Augusto Sakai  [114]    16–12 (1 NC)
# 2  Win - UFC on ESPN+ 7 (St. Peterburg) - Alexey ...  [115]            11–6
# 3   Loss - UFC on ESPN 1 (Phoenix) - Francis Ngannou  [116]            12–3
# 4  USADA suspension for 2 years - for tested posi...   [79]            11–6
# 5              UFC 239 (Las Vegas) - Francis Ngannou  [117]            15–4
#
# 0    MMA record  Heavyweight  0
# 1  27–18 (2 NC)  Heavyweight  0
# 2  45–17 (1 NC)  Heavyweight  0
# 3          14–3  Heavyweight  0
# 4        23–8–1  Heavyweight  0
# 5          21–5  Heavyweight  0

# %% [markdown]
# These rows where not relevant to our project so we dropped them

# %%
to_drop = ['Result / next fight / status',
            'Ref',
           'ISO']
fighters.drop(to_drop, inplace=True, axis=1)

# %% [markdown]
# Changing the first row the the column header messed up the column we added earlier so they needed renaming

# %%
fighters.rename(columns={'Heavyweight':'Weight Class'}, inplace=True)
fighters.rename(columns={0:'Weight Class Index'}, inplace=True)
fighters.head(5)
# Out:
# 0               Name Age                 Ht.      Nickname Endeavor record  \
# 1    Andrei Arlovski  40  6 ft 3 in (1.91 m)  The Pit Bull    16–12 (1 NC)
# 2   Alistair Overeem  38  6 ft 5 in (1.96 m)      The Reem            11–6
# 3     Cain Velasquez  36  6 ft 1 in (1.85 m)           NaN            12–3
# 4    Fabrício Werdum  41  6 ft 4 in (1.93 m)    Vai Cavalo            11–6
# 5  Junior dos Santos  35  6 ft 4 in (1.93 m)        Cigano            15–4
#
# 0    MMA record Weight Class  Weight Class Index
# 1  27–18 (2 NC)  Heavyweight                   0
# 2  45–17 (1 NC)  Heavyweight                   0
# 3          14–3  Heavyweight                   0
# 4        23–8–1  Heavyweight                   0
# 5          21–5  Heavyweight                   0

# %% [markdown]
# The records needed to be cleaned. We removed the dash between the numbers. We then converted them to strings and split them into wins/losses based on their position in the string.

# %%
fighters['MMA record'] = fighters['MMA record'].str.replace('–',' ')
fighters['Endeavor record'] = fighters['Endeavor record'].str.replace('–',' ')

fighters['x'] = fighters['MMA record'].astype(str)
fighters['y'] = fighters['Endeavor record'].astype(str)

# make the new columns using string indexing
fighters['Overall Wins'] = fighters['x'].str[0:2]
fighters['Overall Losses'] = fighters['x'].str[2:5]

fighters['Overall Losses'] = fighters['Overall Losses'].str[0:3]
fighters['Overall Losses'] = fighters['Overall Losses'].str.replace('(',' ')

fighters['UFC Wins'] = fighters['y'].str[0:2]
fighters['UFC Losses'] = fighters['y'].str[2:5]
fighters['UFC Losses'] = fighters['UFC Losses'].str[0:3]
fighters['UFC Losses'] = fighters['UFC Losses'].str.replace('(',' ')

fighters.drop('x', axis=1, inplace=True)
fighters.drop('y', axis=1, inplace=True)

fighters.head(100)
# Out:
# 0                     Name Age                  Ht.             Nickname  \
# 1          Andrei Arlovski  40   6 ft 3 in (1.91 m)         The Pit Bull
# 2         Alistair Overeem  38   6 ft 5 in (1.96 m)             The Reem
# 3           Cain Velasquez  36   6 ft 1 in (1.85 m)                  NaN
# 4          Fabrício Werdum  41   6 ft 4 in (1.93 m)           Vai Cavalo
# 5        Junior dos Santos  35   6 ft 4 in (1.93 m)               Cigano
# 6              Todd Duffee  33   6 ft 4 in (1.93 m)       Irish Car Bomb
# 7             Ben Rothwell  37   6 ft 4 in (1.93 m)                  NaN
# 8           Daniel Cormier  40  5 ft 11 in (1.80 m)                   DC
# 9             Stipe Miočić  36   6 ft 4 in (1.93 m)                  NaN
# 10             Walt Harris  35   6 ft 5 in (1.96 m)       The Big Ticket
# 11           Derrick Lewis  34   6 ft 3 in (1.91 m)          Black Beast
# 12  Marcos Rogério de Lima  33   6 ft 1 in (1.85 m)                Pezão
# 13         Aleksei Oleinik  41   6 ft 2 in (1.88 m)  The Boa Constrictor
# 14            Jarjis Danho  35   6 ft 3 in (1.91 m)         Man Mountain
# 15     Shamil Abdurakhimov  37   6 ft 3 in (1.91 m)                Abrek
# 16       Chris de la Rocha  39   6 ft 3 in (1.91 m)                  NaN
# 17         Francis Ngannou  32   6 ft 4 in (1.93 m)         The Predator
# 18          Curtis Blaydes  28   6 ft 4 in (1.93 m)                Razor
# 19             Cyril Asker  33   6 ft 0 in (1.83 m)           Silverback
# 20           Marcin Tybura  33   6 ft 3 in (1.91 m)                Tybur
# 21        Alexander Volkov  30   6 ft 7 in (2.01 m)                Drago
# 22        Dmitry Smolyakov  36   6 ft 2 in (1.88 m)        The Lifeguard
# 23            Daniel Spitz  28   6 ft 7 in (2.01 m)      Daddy Long Legs
# 24           Justin Willis  31   6 ft 3 in (1.91 m)           Big Pretty
# 25           Júnior Albini  28   6 ft 3 in (1.91 m)                 Baby
# 26           Arjan Bhullar  32   6 ft 1 in (1.85 m)                Singh
# 27            Marcelo Golm  26   6 ft 3 in (1.91 m)                  NaN
# 28          Adam Wieczorek  27   6 ft 5 in (1.96 m)                 Siwy
# 29             Tai Tuivasa  26   6 ft 2 in (1.88 m)              Bam Bam
# 30           Allen Crowder  29   6 ft 3 in (1.91 m)           Pretty Boy
# ..                     ...  ..                  ...                  ...
# 28        Saparbek Safarov  32   6 ft 1 in (1.85 m)                  NaN
# 29              Paul Craig  31   6 ft 4 in (1.93 m)              BearJew
# 30        Bojan Mihajlović  39  5 ft 11 in (1.80 m)                  NaN
# 31         Volkan Oezdemir  29   6 ft 2 in (1.88 m)              No Time
# 32          Dominick Reyes  29   6 ft 4 in (1.93 m)       The Devastator
# 33             Eryk Anders  32   6 ft 2 in (1.88 m)               Ya Boy
# 34      Abdul-Kerim Edilov  27   6 ft 3 in (1.91 m)                  NaN
# 35        Aleksandar Rakić  27   6 ft 5 in (1.96 m)                  NaN
# 36             Gökhan Saki  35   6 ft 0 in (1.83 m)            The Rebel
# 37              Yaozong Hu  24   6 ft 2 in (1.88 m)              Bad Boy
# 38     Michał Oleksiejczuk  24   6 ft 0 in (1.83 m)                 Lord
# 39         Marcin Prachnio  30   6 ft 3 in (1.91 m)                  NaN
# 40        Magomed Ankalaev  26   6 ft 2 in (1.88 m)                  NaN
# 41          Mike Rodriguez  30   6 ft 3 in (1.91 m)                 Slow
# 42            Darko Stošić  27   6 ft 0 in (1.83 m)                  NaN
# 43              Ryan Spann  27   6 ft 5 in (1.96 m)             Superman
# 44           Johnny Walker  27   6 ft 5 in (1.96 m)                  NaN
# 45             Jimmy Crute  24   6 ft 2 in (1.88 m)            The Brute
# 46        Alonzo Menifield  31   6 ft 0 in (1.83 m)                  NaN
# 47        Vinicius Moreira  30   6 ft 4 in (1.93 m)               Mamute
# 48           Klidson Abreu  26   6 ft 2 in (1.88 m)          Urso Branco
# 49     Nicolae Negumereanu  24   6 ft 1 in (1.85 m)                 Nicu
# 50       Kennedy Nzechukwu  26   6 ft 5 in (1.96 m)                  NaN
# 1           Anderson Silva  44   6 ft 2 in (1.88 m)           The Spider
# 2            Luke Rockhold  34   6 ft 3 in (1.91 m)                  NaN
# 3              CB Dollaway  35   6 ft 2 in (1.88 m)         The Doberman
# 4            Ronaldo Souza  39   6 ft 1 in (1.85 m)               Jacaré
# 5             David Branch  37   6 ft 1 in (1.85 m)                  NaN
# 6              Tim Boetsch  38   6 ft 0 in (1.83 m)        The Barbarian
# 7             Brad Tavares  31   6 ft 1 in (1.85 m)                  NaN
#
# 0  Endeavor record    MMA record       Weight Class  Weight Class Index  \
# 1     16 12 (1 NC)  27 18 (2 NC)        Heavyweight                   0
# 2             11 6  45 17 (1 NC)        Heavyweight                   0
# 3             12 3          14 3        Heavyweight                   0
# 4             11 6        23 8 1        Heavyweight                   0
# 5             15 4          21 5        Heavyweight                   0
# 6              3 2           9 3        Heavyweight                   0
# 7              6 5         36 11        Heavyweight                   0
# 8      15 1 (1 NC)   22 1 (1 NC)        Heavyweight                   0
# 9             12 3          18 3        Heavyweight                   0
# 10      5 6 (1 NC)   12 7 (1 NC)        Heavyweight                   0
# 11            12 5   21 7 (1 NC)        Heavyweight                   0
# 12             5 5        16 6 1        Heavyweight                   0
# 13             6 3       57 12 1        Heavyweight                   0
# 14           0 1 1  5 1 1 (1 NC)        Heavyweight                   0
# 15             5 2          20 4        Heavyweight                   0
# 16             1 3           5 3        Heavyweight                   0
# 17             8 2          13 3        Heavyweight                   0
# 18      6 2 (1 NC)   11 2 (1 NC)        Heavyweight                   0
# 19             2 3           9 4        Heavyweight                   0
# 20             4 4          17 5        Heavyweight                   0
# 21             4 1          30 7        Heavyweight                   0
# 22             0 3           9 3        Heavyweight                   0
# 23             1 2           6 2        Heavyweight                   0
# 24             4 1           8 2        Heavyweight                   0
# 25             1 3          14 5        Heavyweight                   0
# 26             3 1           9 1        Heavyweight                   0
# 27             1 3           6 3        Heavyweight                   0
# 28             2 1          10 2        Heavyweight                   0
# 29             3 1           8 1        Heavyweight                   0
# 30             1 1   10 3 (1 NC)        Heavyweight                   0
# ..             ...           ...                ...                 ...
# 28             1 2           9 2  Light heavyweight                   1
# 29             3 3          11 3  Light heavyweight                   1
# 30             0 3          10 6  Light heavyweight                   1
# 31             3 3          15 4  Light heavyweight                   1
# 32             5 0          11 0  Light heavyweight                   1
# 33             3 4          11 4  Light heavyweight                   1
# 34             1 0          17 4  Light heavyweight                   1
# 35             3 0          11 1  Light heavyweight                   1
# 36             1 1           1 2  Light heavyweight                   1
# 37             0 2           3 2  Light heavyweight                   1
# 38      2 0 (1 NC)   14 2 (1 NC)  Light heavyweight                   1
# 39             0 2          13 4  Light heavyweight                   1
# 40             2 1          10 1  Light heavyweight                   1
# 41             1 1          10 3  Light heavyweight                   1
# 42             1 0          13 1  Light heavyweight                   1
# 43             1 0          15 5  Light heavyweight                   1
# 44             3 0          17 3  Light heavyweight                   1
# 45             2 0          10 0  Light heavyweight                   1
# 46             1 0           8 0  Light heavyweight                   1
# 47             0 1           9 2  Light heavyweight                   1
# 48             0 1          14 3  Light heavyweight                   1
# 49             0 1           9 1  Light heavyweight                   1
# 50             0 1           6 1  Light heavyweight                   1
# 1      17 5 (1 NC)   34 9 (1 NC)       Middleweight                   2
# 2              9 3          16 4       Middleweight                   2
# 3             11 9          17 9       Middleweight                   2
# 4             12 5   26 7 (1 NC)       Middleweight                   2
# 5              4 5          22 6       Middleweight                   2
# 6            12 12         21 13       Middleweight                   2
# 7             12 5          17 5       Middleweight                   2
#
# 0  Overall Wins Overall Losses UFC Wins UFC Losses
# 1            27             18       16         12
# 2            45             17       11          6
# 3            14              3       12          3
# 4            23             8        11          6
# 5            21              5       15          4
# 6            9               3       3           2
# 7            36             11       6           5
# 8            22             1        15         1
# 9            18              3       12          3
# 10           12             7        5         6
# 11           21             7        12          5
# 12           16             6        5           5
# 13           57             12       6           3
# 14           5             1 1       0         1 1
# 15           20              4       5           2
# 16           5               3       1           3
# 17           13              3       8           2
# 18           11             2        6         2
# 19           9               4       2           3
# 20           17              5       4           4
# 21           30              7       4           1
# 22           9               3       0           3
# 23           6               2       1           2
# 24           8               2       4           1
# 25           14              5       1           3
# 26           9               1       3           1
# 27           6               3       1           3
# 28           10              2       2           1
# 29           8               1       3           1
# 30           10             3        1           1
# ..          ...            ...      ...        ...
# 28           9               2       1           2
# 29           11              3       3           3
# 30           10              6       0           3
# 31           15              4       3           3
# 32           11              0       5           0
# 33           11              4       3           4
# 34           17              4       1           0
# 35           11              1       3           0
# 36           1               2       1           1
# 37           3               2       0           2
# 38           14             2        2         0
# 39           13              4       0           2
# 40           10              1       2           1
# 41           10              3       1           1
# 42           13              1       1           0
# 43           15              5       1           0
# 44           17              3       3           0
# 45           10              0       2           0
# 46           8               0       1           0
# 47           9               2       0           1
# 48           14              3       0           1
# 49           9               1       0           1
# 50           6               1       0           1
# 1            34             9        17         5
# 2            16              4       9           3
# 3            17              9       11          9
# 4            26             7        12          5
# 5            22              6       4           5
# 6            21             13       12         12
# 7            17              5       12          5
#
# [100 rows x 12 columns]

# %% [markdown]
# Daniel Cormier appeares in two weight classes, which is a rare occurence.This was messing up a graph later on so he was dropped from his old weight class.

# %%
fighters = fighters[~((fighters['Name'] == 'Daniel Cormier') & (fighters['Weight Class'] == 'Light heavyweight'))]

fighters.loc[fighters['Name'] == 'Daniel Cormier']
# Out:
# 0            Name Age                  Ht. Nickname Endeavor record  \
# 8  Daniel Cormier  40  5 ft 11 in (1.80 m)       DC     15 1 (1 NC)
#
# 0   MMA record Weight Class  Weight Class Index Overall Wins Overall Losses  \
# 8  22 1 (1 NC)  Heavyweight                   0           22             1
#
# 0 UFC Wins UFC Losses
# 8       15         1

# %% [markdown]
# These fighters names were different on the UFC website than on wikipedia for various reasons so I changed them for the merge

# %%
fighters['Name'] = fighters['Name'].replace('Khalil Rountree', 'Khalil Rountree Jr.')
fighters['Name'] = fighters['Name'].replace('Joseph Duffy', 'Joe Duffy')
fighters['Name'] = fighters['Name'].replace('Emil Weber Meek', 'Emil Meek')
fighters['Name'] = fighters['Name'].replace('Sergey Pavlovich', 'Sergei Pavlovich')
fighters['Name'] = fighters['Name'].replace('Jan Błachowicz', 'Jan Blachowicz')
fighters['Name'] = fighters['Name'].replace('Yaozong Hu', 'Hu Yaozong') 
fighters['Name'] = fighters['Name'].replace('Josh Burkman', 'Joshua Burkman')  
fighters['Name'] = fighters['Name'].replace('Brad Scott', 'Bradley Scott')  
fighters['Name'] = fighters['Name'].replace('Jingliang Li', 'Li Jingliang')  
fighters['Name'] = fighters['Name'].replace('Kenan Song', 'Song Kenan')  
fighters['Name'] = fighters['Name'].replace('Carlo Pedersoli Jr.', 'Carlo Pedersoli')  
fighters['Name'] = fighters['Name'].replace('B.J.-Penn', 'BJ Penn')  
fighters['Name'] = fighters['Name'].replace('Diego Ferreira', 'Diego Ferreira')  
fighters['Name'] = fighters['Name'].replace('Marco Reyes', 'Marco Polo Reyes')  
fighters['Name'] = fighters['Name'].replace('Doo ho Choi', 'Dooho Choi')  
fighters['Name'] = fighters['Name'].replace('Guan Wang', 'Wang Guan')  
fighters['Name'] = fighters['Name'].replace('Yadong Song', 'Song Yadong') 
fighters['Name'] = fighters['Name'].replace('Yadong Song', 'Sean O"Malley')
fighters['Name'] = fighters['Name'].replace('France Kai Kara', 'Kai Kara France')
fighters['Name'] = fighters['Name'].replace('Aleksandra Albu', 'Alexandra Albu')
fighters['Name'] = fighters['Name'].replace('Xiaonan Yan', 'Yan Xiaonan')
fighters['Name'] = fighters['Name'].replace('Souza Livinha', 'Livinha Souza') 
fighters['Name'] = fighters['Name'].replace('Fabricio Werdum ', 'Fabricio Werdum')

# %% [markdown]
# ## Height Cleaning

# %% [markdown]
# The metric part of the height was removed and the imoerial was changed from feet to inches

# %%
fighters = fighters[pd.notnull(fighters["Ht."])]
fighters['Ht.'] = fighters['Ht.'].map(lambda x: x.split('(')[1].strip())
fighters['Ht.'] = fighters['Ht.'].map(lambda x: x.split('m')[0].strip())
fighters['Ht.'] = fighters['Ht.'].apply(ast.literal_eval)
fighters['Ht.']= fighters['Ht.'].apply(lambda x: x* 39.37)

# %%
fighters.head(5)
# Out:
# 0               Name Age      Ht.      Nickname Endeavor record    MMA record  \
# 1    Andrei Arlovski  40  75.1967  The Pit Bull    16 12 (1 NC)  27 18 (2 NC)
# 2   Alistair Overeem  38  77.1652      The Reem            11 6  45 17 (1 NC)
# 3     Cain Velasquez  36  72.8345           NaN            12 3          14 3
# 4    Fabrício Werdum  41  75.9841    Vai Cavalo            11 6        23 8 1
# 5  Junior dos Santos  35  75.9841        Cigano            15 4          21 5
#
# 0 Weight Class  Weight Class Index Overall Wins Overall Losses UFC Wins  \
# 1  Heavyweight                   0           27             18       16
# 2  Heavyweight                   0           45             17       11
# 3  Heavyweight                   0           14              3       12
# 4  Heavyweight                   0           23             8        11
# 5  Heavyweight                   0           21              5       15
#
# 0 UFC Losses
# 1         12
# 2          6
# 3          3
# 4          6
# 5          4

# %%
fighters.shape
# Out:
# (587, 12)

# %% [markdown]
# Export the dataframe to a csv

# %%
 fighters.to_csv('wiki_scrape.csv',index = False)
